# %%
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline

#[confidence/10, nervousness/10, subject, above 4, above 6, highest or lowest]
grades = [[8, 3, "Math", 1, 0, 1], [9, 1, "English", 1, 1, 0], [7, 2, "History", 1, 0, 1], [9, 1, "Geography", 1, 1, 0]]
mystery_grade = [7, 3, "Math"]
grade_possible = [4, 6, 8]
gradeNum = 0


w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()

def sigmoid(x):
    return 1/(1 + np.exp(-x))
def sigmoidPrime(x):
    return sigmoid(x) * (1 - sigmoid(x))

costs = []

for i in range(2000):
    learning_rate = 0.688
    
    randomInt = np.random.randint(len(grades))
    point = grades[randomInt]
    
    y = w1 * point[0] + w2 * point[1] + b
    
    prediction1 = sigmoid(y)
    target = point[3]
    
    cost = (prediction1 - target) ** 2
    costs.append(cost)
    
    dcost_pred = 2 * (prediction1 - target)
    dpred_dy = sigmoidPrime(y)
    
    dy_dw1 = point[0]
    dy_dw2 = point[1]
    dy_db = 1
    
    dcost_w1 = dcost_pred * dpred_dy * dy_dw1
    dcost_w2 = dcost_pred * dpred_dy * dy_dw2
    dcost_b = dcost_pred * dpred_dy * dy_db
    
    w1 -= learning_rate * dcost_w1
    w2 -= learning_rate * dcost_w2
    b -= learning_rate * dcost_b
    
    if i % 100 == 0:
        cost_sum = 0
        for j in range(len(grades)):
            point = grades[randomInt]
            
            y = point[0] * w1 + point[1] * w2 + b
            prediction1 = sigmoid(y)
            
            target = point[3]
            
            cost_sum += (prediction - target) ** 2
            costs.append(cost_sum/len(grades))
            
plt.plot(costs)

y = mystery_grade[0] *  w1 + mystery_grade[1] * w2 + b
prediction1 = sigmoid(y)

if prediction1 >= 0.5:
    mystery_grade.append(1)
else:
    mystery_grade.append(0)

    
    
costs = []

for i in range(2000):
    learning_rate = 0.688
    
    randomInt = np.random.randint(len(grades))
    point = grades[randomInt]
    
    y = w1 * point[0] + w2 * point[1] + b
    
    prediction2 = sigmoid(y)
    target = point[4]
    
    cost = (prediction2 - target) ** 2
    costs.append(cost)
    
    dcost_pred = 2 * (prediction2 - target)
    dpred_dy = sigmoidPrime(y)
    
    dy_dw1 = point[0]
    dy_dw2 = point[1]
    dy_db = 1
    
    dcost_w1 = dcost_pred * dpred_dy * dy_dw1
    dcost_w2 = dcost_pred * dpred_dy * dy_dw2
    dcost_b = dcost_pred * dpred_dy * dy_db
    
    w1 -= learning_rate * dcost_w1
    w2 -= learning_rate * dcost_w2
    b -= learning_rate * dcost_b
    
    if i % 100 == 0:
        cost_sum = 0
        for j in range(len(grades)):
            point = grades[randomInt]
            
            y = point[0] * w1 + point[1] * w2 + b
            prediction2 = sigmoid(y)
            
            target = point[4]
            
            cost_sum += (prediction - target) ** 2
            costs.append(cost_sum/len(grades))
            
plt.plot(costs)

y = mystery_grade[0] *  w1 + mystery_grade[1] * w2 + b
prediction2 = sigmoid(y)

if prediction2 >= 0.5:
    mystery_grade.append(1)
else:
    mystery_grade.append(0)

    
    
costs = []

for i in range(2000):
    learning_rate = 0.688
    
    randomInt = np.random.randint(len(grades))
    point = grades[randomInt]
    
    y = w1 * point[0] + w2 * point[1] + b
    
    prediction3 = sigmoid(y)
    target = point[5]
    
    cost = (prediction3 - target) ** 2
    costs.append(cost)
    
    dcost_pred = 2 * (prediction3 - target)
    dpred_dy = sigmoidPrime(y)
    
    dy_dw1 = point[0]
    dy_dw2 = point[1]
    dy_db = 1
    
    dcost_w1 = dcost_pred * dpred_dy * dy_dw1
    dcost_w2 = dcost_pred * dpred_dy * dy_dw2
    dcost_b = dcost_pred * dpred_dy * dy_db
    
    w1 -= learning_rate * dcost_w1
    w2 -= learning_rate * dcost_w2
    b -= learning_rate * dcost_b
    
    if i % 100 == 0:
        cost_sum = 0
        for j in range(len(grades)):
            point = grades[randomInt]
            
            y = point[0] * w1 + point[1] * w2 + b
            prediction3 = sigmoid(y)
            
            target = point[5]
            
            cost_sum += (prediction3 - target) ** 2
            costs.append(cost_sum/len(grades))
            
plt.plot(costs)

y = mystery_grade[0] *  w1 + mystery_grade[1] * w2 + b
prediction3 = sigmoid(y)

if prediction3 >= 0.5:
    mystery_grade.append(1)
else:
    mystery_grade.append(0)


    
if mystery_grade[3] == 1:
    gradeNum > 4
else:
    gradeNum <=4

if mystery_grade[4] == 1:
    gradeNum > 6
    
else:
    gradeNum <= 6 and gradeNum > 4
    
    
if gradeNum <= 4 and mystery_grade[5] == 1:
    grade = 4
elif gradeNum <= 4 and mystery_grade[5] != 1:
    grade = "3 or below :("
    
if mystery_grade[4] == 1 and mystery_grade[5] == 1:
    grade = 8
elif mystery_grade[4] == 1 and mystery_grade[5] != 1:
    grade = 7
    
    
if mystery_grade[4] == 0 and mystery_grade[5] == 1:
    grade = 6
elif mystery_grade[4] == 0 and mystery_grade[5] == 0:
    grade = 5
    
print("Your grade is... " + str(grade))
# Out:
# Your grade is... 8
